# %% [markdown]
# ## Importación de librerias y definición de funciones

# %%
from functions.PPTX_CHARTER_KT_THEME import *

# %% [markdown]
# ## Reporte

# %%
# Mapeo de labels customizados para identificar variables relevantes en la construcción del reporte 

config = {
    'L1 Label de marca': ' Carnation',
    'L1 Label de categoría': 'Categoría',
    'L0 Label de ventas': 'Sales',
    'L0 Label de distribución': 'Nominal Dist.',
    'L0 Label de descuento': 'Pricing Discount',
    'L0 Label de precio': 'Price',
    'L0 Label de macroeconómicos': 'Macroeconomic',
    'Metric Label de ventas en volumen': 'L',
    'L0 Label media organica': 'Organic Media'
}

# %%
# Opcional: Añadir el color de la marca del cliente a la paleta 
original_pallete = [color for color in standard_pallete]
client_color = RGBColor(147,0,46)
standard_pallete.insert(0, client_color)

# %%
# Carga de datos 
data = pd.read_pickle('Output_Stacked_Data.pkl')

# Conversion de variable de periodo a string 
data['Period_str'] = data['Period'].dt.strftime('%Y-%m') # Formato para modelos mensuales '%Y-%m' || Formato para modelos semanales '%Y-%m-%d'

# Aplicar filtros relevantes en caso de ser necesario 
data = data[(data['Breaks']!='FY\'21') & (data['Breaks']!='FY\'25')]

# %% [markdown]
# ### Sección 0: Inicialización del documento y portada

# %%
# Inicialización de la presentación y selección de slide layouts 
prs = Presentation('./pptx_template/Kantar Master Template.pptx')

layout_title_white = prs.slide_layouts[0]
layout_section_header_white = prs.slide_layouts[4]
layout_content_one = prs.slide_layouts[8]
layout_content_two = prs.slide_layouts[10]
layout_blank = prs.slide_layouts[22]

# %%
# Slide de titulo 
title_slide = prs.slides.add_slide(layout_title_white)

title_slide.placeholders[0].text = 'Data Review Deck'
title_slide.placeholders[1].text = 'Marca'

# %% [markdown]
# ### Sección 1: Ventas

# %%
# Header slide: Ventas
header_1_slide = prs.slides.add_slide(layout_section_header_white)

header_1_slide.placeholders[15].text = 'Ventas'

# %%
# Ventas de la categoría en volumen
chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    stacked_df=data,
    slide_title='Ventas de la categoría',
    category_vars=['Breaks'],
    series_vars=['L1'],
    iterable_vars=['Metric'],
    filter_mask=(data['L0']==config['L0 Label de ventas']) & (data['L1']!=config['L1 Label de categoría']),
    value_var='value',
    chart_type=XL_CHART_TYPE.COLUMN_STACKED,
    show_data_labels_perc=True
)

# %%
# Ventas de la categoría en ingreso
slide_temp = prs.slides.add_slide(layout_blank)

slide_temp.placeholders[0].text = 'Ventas de la categoría'

chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    use_slide_object=True,
    slide_object=slide_temp,
    stacked_df=data,
    category_vars=['Breaks'],
    series_vars=['L1'],
    value_var='value',
    filter_mask=(data['L0']==config['L0 Label de ventas']) & (data['L1']!=config['L1 Label de categoría']) & (data['Metric'] == '$'),
    pos_horizontal=Inches(0.39),
    pos_vertical=Inches(1.87),
    width=Inches(6.15),
    height=Inches(4.37),
    show_data_labels_perc=True
)

chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    use_slide_object=True,
    slide_object=slide_temp,
    stacked_df=data,
    category_vars=['Breaks'],
    series_vars=['L1'],
    value_var='value',
    filter_mask=(data['L0']==config['L0 Label de ventas']) & (data['L1']!=config['L1 Label de categoría']) & (data['Metric'] == config['Metric Label de ventas en volumen']),
    pos_horizontal=Inches(6.78),
    pos_vertical=Inches(1.87),
    width=Inches(6.15),
    height=Inches(4.37),
    show_data_labels_perc=True
)

# %%
# Ventas de la categoría en volumen e ingreso. Slide con grafico lado a lado.
slide_temp = prs.slides.add_slide(layout_blank)

slide_temp.placeholders[0].text = 'Ventas de la marca'

chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    use_slide_object=True,
    slide_object=slide_temp,
    stacked_df=data,
    category_vars=['Breaks'],
    series_vars=['L1'],
    value_var='value',
    filter_mask=(data['L0']==config['L0 Label de ventas']) & (data['L1']==config['L1 Label de marca']) & (data['Metric'] == '$'),
    pos_horizontal=Inches(0.39),
    pos_vertical=Inches(1.87),
    width=Inches(6.15),
    height=Inches(4.37),
    show_data_labels_perc=False,
    show_legend=False
)

chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    use_slide_object=True,
    slide_object=slide_temp,
    stacked_df=data,
    category_vars=['Breaks'],
    series_vars=['L1'],
    value_var='value',
    filter_mask=(data['L0']==config['L0 Label de ventas']) & (data['L1']==config['L1 Label de marca']) & (data['Metric'] == config['Metric Label de ventas en volumen']),
    pos_horizontal=Inches(6.78),
    pos_vertical=Inches(1.87),
    width=Inches(6.15),
    height=Inches(4.37),
    show_data_labels_perc=False,
    show_legend=False
)

# %%
# Tabla de ventas en volumen
table_maker(
    press_object=prs,
    layout_object=layout_blank,
    slide_title='Ventas en volumen (miles L)',
    stacked_df=data,
    value_var='value',
    category_vars=['L1'],
    series_vars=['Breaks'],
    filter_mask=(data['L0']=='Sales') & (data['Metric']==config['Metric Label de ventas en volumen']),
    table_value_scale=1000,
    decimal_places=1,
    show_PoP_change=True,
    show_share_perc=False
)

# %%
# Tabla de ventas en ingreso
table_maker(
    press_object=prs,
    layout_object=layout_blank,
    slide_title='Ventas en ingreso (millones MXN)',
    stacked_df=data,
    value_var='value',
    category_vars=['L1'],
    series_vars=['Breaks'],
    filter_mask=(data['L0']=='Sales') & (data['Metric']=='$'),
    table_value_scale=1000000,
    decimal_places=1,
    show_PoP_change=True,
    show_share_perc=False
)

# %%
# Header 2 Variables de marca 
header_2_slide = prs.slides.add_slide(layout_section_header_white)

header_2_slide.placeholders[15].text = 'Variables de marca, categoría y macroeconómicas'

# %%
# Chart de distribución
chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    stacked_df=data,
    slide_title='Distribución',
    category_vars=['Period_str'],
    series_vars=['L1'],
    filter_mask=(data['L0']==config['L0 Label de distribución']),
    value_var='value',
    chart_type=XL_CHART_TYPE.LINE,
    show_legend=False,
    show_data_labels_perc=False
)

# %%
# Price vs Pricing Discount series
chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    stacked_df=data,
    slide_title='Precio de la marca y serie de descuento ##AJUSTAR ESCALA DEL GRAFICO##',
    category_vars=['Period_str'],
    series_vars=['L0','Metric'],
    filter_mask=((data['L0']==config['L0 Label de precio']) | (data['L0']==config['L0 Label de descuento'])) & (data['L1']==config['L1 Label de marca']),
    value_var='value',
    chart_type=XL_CHART_TYPE.LINE,
    show_legend=True,
    show_data_labels_perc=False
)

# %%
# Precios de la categoría
chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    stacked_df=data,
    slide_title='Precio',
    category_vars=['Period_str'],
    series_vars=['L1'],
    filter_mask=(data['L0']==config['L0 Label de precio']),
    value_var='value',
    chart_type=XL_CHART_TYPE.LINE,
    show_legend=True,
    show_data_labels_perc=False
)

# %%
# Macroeconomicos
chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    slide_title='Macroeconómicos',
    stacked_df=data,
    category_vars=['Period_str'],
    series_vars=['Metric'],
    value_var='value',
    iterable_vars=['L2','L3','L4'],
    filter_mask=(data['L0']==config['L0 Label de macroeconómicos']),
    chart_type=XL_CHART_TYPE.LINE
)

# %% [markdown]
# ### Sección 2: Medios pagados

# %%
# Header slide de medios pagados
header_3_slide = prs.slides.add_slide(layout_section_header_white)

header_3_slide.placeholders[15].text = 'Medios pagados'

# %%
# Slide de inversion en medios pagados 
chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    slide_title='Inversión en medios pagados',
    stacked_df=data,
    category_vars=['Breaks'],
    series_vars=['L3'],
    value_var='value',
    filter_mask=(data['L0']=='Media') & (data['Metric Type']=='Spend'),
    show_data_labels_perc=True
)

# %%
# Slide de inversion en medios a la izquierda y ventas en volumen a la derecha 
slide_temp = prs.slides.add_slide(layout_blank)

slide_temp.placeholders[0].text = 'Inversion en medios vs ventas en volumen'

chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    use_slide_object=True,
    slide_object=slide_temp,
    slide_title='Inversión en medios pagados',
    stacked_df=data,
    category_vars=['Breaks'],
    series_vars=['L3'],
    value_var='value',
    filter_mask=(data['L0']=='Media') & (data['Metric Type']=='Spend'),
    show_data_labels_perc=True,
    pos_horizontal=Inches(0.39),
    pos_vertical=Inches(1.87),
    width=Inches(6.15),
    height=Inches(4.37)
)

chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    use_slide_object=True,
    slide_object=slide_temp,
    stacked_df=data,
    category_vars=['Breaks'],
    series_vars=['L1'],
    value_var='value',
    filter_mask=(data['L0']==config['L0 Label de ventas']) & (data['L1']==config['L1 Label de marca']) & (data['Metric'] == config['Metric Label de ventas en volumen']),
    pos_horizontal=Inches(6.78),
    pos_vertical=Inches(1.87),
    width=Inches(6.15),
    height=Inches(4.37),
    show_data_labels_perc=False,
    show_legend=False
)

# %%
# Serie de tiempo de inversion en medios vs ventas 
slide_temp = prs.slides.add_slide(layout_blank)

slide_temp.placeholders[0].text = 'Inversion en medios vs ventas en volumen ### GRAFICO DE VENTAS ENCIMA: PIMPEAR ###'

chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    use_slide_object=True,
    slide_object=slide_temp,
    stacked_df=data,
    category_vars=['Period_str'],
    series_vars=['L3'],
    value_var='value',
    filter_mask=(data['L0']=='Media') & (data['Metric Type']=='Spend'),
)

chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    use_slide_object=True,
    slide_object=slide_temp,
    stacked_df=data,
    category_vars=['Period_str'],
    series_vars=['L1'],
    value_var='value',
    filter_mask=(data['L0']==config['L0 Label de ventas']) & (data['L1']==config['L1 Label de marca']) & (data['Metric'] == config['Metric Label de ventas en volumen']),
    show_data_labels_perc=False,
    show_legend=False,
    chart_type=XL_CHART_TYPE.LINE
)

# %%
# Grafico de inversion de medios a la izquierda y tabla de inversion a la derecha 
slide_temp = prs.slides.add_slide(layout_blank)

slide_temp.placeholders[0].text = 'Inversion en medios'

chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    use_slide_object=True,
    slide_object=slide_temp,
    stacked_df=data,
    category_vars=['Breaks'],
    series_vars=['L3'],
    value_var='value',
    filter_mask=(data['L0']=='Media') & (data['Metric Type']=='Spend'),
    show_data_labels_perc=True,
    pos_horizontal=Inches(0.39),
    pos_vertical=Inches(1.87),
    width=Inches(6.15),
    height=Inches(4.37)
)

table_maker(
    press_object=prs,
    layout_object=layout_blank,
    use_slide_object=True,
    slide_object=slide_temp,
    stacked_df=data,
    category_vars=['L3','L4'],
    series_vars=['Breaks'],
    value_var='value',
    filter_mask=(data['L0']=='Media') & (data['Metric Type']=='Spend'),
    use_multilevel_categories=True,
    table_value_scale=1000,
    decimal_places=1,
    show_PoP_change=True,
    show_share_perc=False,
    pos_horizontal=Inches(6.78),
    pos_vertical=Inches(1.87),
    width=Inches(6.15),
    height=Inches(4.37)
)

# %%
# Zoom en actividad de medios pagados 
chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    stacked_df=data,
    slide_title='Actividad en medios pagados',
    category_vars=['Period_str'],
    series_vars=['Metric'],
    value_var='value',
    iterable_vars=['L4','Metric'],
    grouping_vars=['L3'],
    filter_mask=(data['L0']=='Media') & (data['Metric Type']=='Effort'),
    show_legend=False,
    chart_type=XL_CHART_TYPE.COLUMN_CLUSTERED
)

# %%
# Zoom en actividad de medios organicos  
chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    stacked_df=data,
    slide_title='Actividad en medios organicos',
    category_vars=['Period_str'],
    series_vars=['Metric'],
    value_var='value',
    iterable_vars=['L4','Metric'],
    grouping_vars=['L3'],
    filter_mask=(data['L0']==config['L0 Label media organica']) & (data['Metric Type']=='Effort'),
    show_legend=False,
    chart_type=XL_CHART_TYPE.COLUMN_CLUSTERED
)

# %% [markdown]
# ## Output

# %%
df_cost_per_act = pd.read_pickle('Output_cost_per_act.pkl')

df_cost_per_act = pd.merge(
    left=df_cost_per_act,
    right=data[['Period','Breaks']].drop_duplicates(),
    left_on='Period',
    right_on='Period'
)

df_cost_per_act = df_cost_per_act.drop(columns=['Period'])

df_cost_per_act = df_cost_per_act.groupby('Breaks').mean().T

# %%
table_maker(
    press_object=prs,
    layout_object=layout_blank,
    slide_title='TEST custom table',
    show_PoP_change=True,    
    crosstab_override=df_cost_per_act
)

# %%
chart_maker(
    press_object=prs,
    layout_object=layout_blank,
    slide_title='Experiment with custom dfs',
    chart_type=XL_CHART_TYPE.COLUMN_CLUSTERED,
    show_legend=True,
    crosstab_override=df_cost_per_act
)

# %%
df_cost_per_act
# Out:
# Breaks                                                   FY'22       FY'23  \
# Medios pagados Web Adsmovil Effort Impresiones             NaN         NaN
# Medios pagados E-commerce Amazon Display Effort...   89.635365         NaN
# Medios pagados Streaming Amazon Prime Video Eff...         NaN         NaN
# Medios pagados E-commerce Amazon Search Effort ...  116.419243         NaN
# Medios pagados TV Azteca Effort Impresiones           6.868534         NaN
# Medios pagados Medios tradicionales Cine Effort...         NaN         NaN
# Medios pagados Web Contenido Effort Impresiones       0.400000         NaN
# Medios pagados Web Criteo Effort Impresiones               NaN         NaN
# Medios pagados TV CTV Effort Impresiones              7.600887    7.567080
# Medios pagados Web Demand G Effort Impresiones             NaN  102.649485
# Medios pagados Web Digital Wifi Metro Effort Im...         NaN    6.666667
# Medios pagados Medios tradicionales DOOH Effort...         NaN   18.181818
# Medios pagados Web Dynamic Effort Impresiones         8.194015         NaN
# Medios pagados Web Estandar Banner Effort Impre...         NaN  256.608687
# Medios pagados Redes sociales Facebook Consider...   71.317004   91.858489
# Medios pagados Redes sociales Facebook Encounte...  134.706457   58.806889
# Medios pagados Redes sociales Facebook Purchase...   72.350774  137.139015
# Medios pagados Redes sociales Facebook Repurcha...   45.504608   84.236553
# Medios pagados Web PMAX Effort Impresiones                 NaN         NaN
# Medios pagados Medios tradicionales Radio Effor...         NaN         NaN
# Medios pagados Search Google Effort Impresiones       1.355336    1.026154
# Medios pagados Streaming Spotify Effort Impresi...         NaN         NaN
# Medios pagados Web Teads Effort Impresiones          15.381447   15.797486
# Medios pagados Redes sociales Tik Tok Effort Im...         NaN   73.529412
# Medios pagados Streaming Youtube Effort Impresi...   40.953356   67.930353
# Medios pagados TV Open TV Effort TRPs                 0.000063    0.000056
# Medios pagados TV Open TV Effort Frecuencia                NaN    0.000005
# Medios pagados TV Open TV Effort Reach 1+                  NaN    0.000029
# Medios pagados TV Open TV Effort Reach 3+                  NaN    0.000019
# Medios pagados TV Pay TV Effort TRPs                  0.000600    0.000601
# Medios pagados Medios tradicionales OOH Effort ...         NaN         NaN
#
# Breaks                                                   FY'24
# Medios pagados Web Adsmovil Effort Impresiones       15.671627
# Medios pagados E-commerce Amazon Display Effort...         NaN
# Medios pagados Streaming Amazon Prime Video Eff...    5.954507
# Medios pagados E-commerce Amazon Search Effort ...         NaN
# Medios pagados TV Azteca Effort Impresiones           0.150000
# Medios pagados Medios tradicionales Cine Effort...    2.857143
# Medios pagados Web Contenido Effort Impresiones       0.348432
# Medios pagados Web Criteo Effort Impresiones         46.313043
# Medios pagados TV CTV Effort Impresiones              4.710212
# Medios pagados Web Demand G Effort Impresiones             NaN
# Medios pagados Web Digital Wifi Metro Effort Im...         NaN
# Medios pagados Medios tradicionales DOOH Effort...         NaN
# Medios pagados Web Dynamic Effort Impresiones              NaN
# Medios pagados Web Estandar Banner Effort Impre...  166.666667
# Medios pagados Redes sociales Facebook Consider...   74.570244
# Medios pagados Redes sociales Facebook Encounte...   29.431530
# Medios pagados Redes sociales Facebook Purchase...   82.038459
# Medios pagados Redes sociales Facebook Repurcha...         NaN
# Medios pagados Web PMAX Effort Impresiones           56.914095
# Medios pagados Medios tradicionales Radio Effor...    0.000052
# Medios pagados Search Google Effort Impresiones            NaN
# Medios pagados Streaming Spotify Effort Impresi...    4.746557
# Medios pagados Web Teads Effort Impresiones                NaN
# Medios pagados Redes sociales Tik Tok Effort Im...   85.300634
# Medios pagados Streaming Youtube Effort Impresi...   38.077015
# Medios pagados TV Open TV Effort TRPs                 0.000033
# Medios pagados TV Open TV Effort Frecuencia           0.000003
# Medios pagados TV Open TV Effort Reach 1+             0.000013
# Medios pagados TV Open TV Effort Reach 3+             0.000008
# Medios pagados TV Pay TV Effort TRPs                  0.000600
# Medios pagados Medios tradicionales OOH Effort ...    0.000363

# %%
prs.save('Preanalysis Report Output.pptx')
